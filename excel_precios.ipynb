# %%
import pandas as pd
from datetime import datetime
import numpy as np

#file_price = 'preciosEESS_es'
file_price = 'embarcacionesPrecios_es'
df = pd.read_excel(file_price + '.xls', skiprows=3)

# Agregar una columna "Tipo estación"
df['Tipo estación'] = 'Terrestre' if file_price == 'preciosEESS_es' else 'Puerto'

df.head()  # Mostramos las primeras filas del DataFrame
# Out:
#   Provincia             Municipio             Localidad  Código postal  \
# 0  ALICANTE                 ALTEA                 ALTEA           3590
# 1  ALICANTE            CALPE/CALP                 CALPE           3710
# 2  ALICANTE                 DÉNIA                 DENIA           3700
# 3  ALICANTE                 DÉNIA                 DENIA           3700
# 4  ALICANTE  GUARDAMAR DEL SEGURA  GUARDAMAR DEL SEGURA           3140
#
#                                            Dirección   Longitud    Latitud  \
# 0  PUERTO DEPORTIVO LUIS CAMPOMANES, S/N - PARTID...  -0,003833  38,629556
# 1                  EXPLANADA DEL PUERTO PESQUERO S/N   0,069162  38,637313
# 2                       PUERTO PESQUERO DE DENIA S/N   0,113056  38,843611
# 3               DARSENA DE BABOR S/N PUERTO DE DENIA   0,119139  38,567556
# 4                               AVDA. DEL PUERTO.219  -0,646278  38,109000
#
#   Precio gasolina 95 E5 Precio gasolina 95 E10 Precio gasóleo A  \
# 0                 1,680                    NaN            1,550
# 1                   NaN                    NaN              NaN
# 2                   NaN                    NaN              NaN
# 3                 1,669                    NaN            1,509
# 4                   NaN                    NaN              NaN
#
#   Precio gasóleo B Precio gasóleo de uso marítimo  \
# 0              NaN                            NaN
# 1          802,200                            NaN
# 2              NaN                        640,000
# 3              NaN                            NaN
# 4              NaN                        735,000
#
#                             Rótulo  \
# 0                              NaN
# 1  COFRADIA DE PESCADORES DE CALPE
# 2                           NO HAY
# 3              MARINA DE DENIA S.A
# 4     MARINA DE LAS DUNAS (REPSOL)
#
#                                    Tipo venta Rem.  \
# 0  Suministro a barcos deportivos o de recreo   dm
# 1                                       Mixto   dm
# 2                      Suministro a pesqueros   dm
# 3  Suministro a barcos deportivos o de recreo   dm
# 4                                       Mixto   dm
#
#                                           Horario Tipo estación
# 0                                M-D: 10:00-18:00        Puerto
# 1  L-V: 08:00-13:30 y 15:30-19:30; S: 09:00-13:00        Puerto
# 2                  L-V: 08:00-13:00 y 16:30-19:30        Puerto
# 3                                        L-D: 24H        Puerto
# 4                                L-D: 07:00-22:00        Puerto

# %%
df.info() # Información general sobre el DataFrame (tipos de datos, valores nulos, etc.)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131 entries, 0 to 130
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Provincia                       131 non-null    object
#  1   Municipio                       131 non-null    object
#  2   Localidad                       131 non-null    object
#  3   Código postal                   131 non-null    int64
#  4   Dirección                       131 non-null    object
#  5   Longitud                        124 non-null    object
#  6   Latitud                         124 non-null    object
#  7   Precio gasolina 95 E5           78 non-null     object
#  8   Precio gasolina 95 E10          1 non-null      object
#  9   Precio gasóleo A                82 non-null     object
#  10  Precio gasóleo B                73 non-null     object
#  11  Precio gasóleo de uso marítimo  9 non-null      object
#  12  Rótulo                          127 non-null    object
#  13  Tipo venta                      131 non-null    object
#  14  Rem.                            131 non-null    object
#  15  Horario                         131 non-null    object
#  16  Tipo estación                   131 non-null    object
# dtypes: int64(1), object(16)
# memory usage: 17.5+ KB

# %%
# Cuenta los duplicados
for column in df.columns:
  num_duplicates = df.duplicated(subset=[column]).sum()
  print(f"La columna '{column}' tiene {num_duplicates} elementos duplicados.")
# Out:
# La columna 'Provincia' tiene 111 elementos duplicados.
# La columna 'Municipio' tiene 23 elementos duplicados.
# La columna 'Localidad' tiene 16 elementos duplicados.
# La columna 'Código postal' tiene 13 elementos duplicados.
# La columna 'Dirección' tiene 30 elementos duplicados.
# La columna 'Longitud' tiene 6 elementos duplicados.
# La columna 'Latitud' tiene 6 elementos duplicados.
# La columna 'Precio gasolina 95 E5' tiene 74 elementos duplicados.
# La columna 'Precio gasolina 95 E10' tiene 129 elementos duplicados.
# La columna 'Precio gasóleo A' tiene 70 elementos duplicados.
# La columna 'Precio gasóleo B' tiene 94 elementos duplicados.
# La columna 'Precio gasóleo de uso marítimo' tiene 121 elementos duplicados.
# La columna 'Rótulo' tiene 75 elementos duplicados.
# La columna 'Tipo venta' tiene 128 elementos duplicados.
# La columna 'Rem.' tiene 129 elementos duplicados.
# La columna 'Horario' tiene 83 elementos duplicados.
# La columna 'Tipo estación' tiene 130 elementos duplicados.

# %%
# Convertirmos la columna 'Código postal' a cadena de texto (string)
df['Código postal'] = df['Código postal'].astype(str)
# Asegurarse de que la columna 'Código postal' tenga una longitud de 5 dígitos
df['Código postal'] = df['Código postal'].str.zfill(5)

# Quitamos columnas
df = df.drop('% bioalcohol', axis=1, errors='ignore')
df = df.drop('% éster metílico', axis=1, errors='ignore')
df = df.drop('Tipo venta', axis=1)
df = df.drop('Rem.', axis=1)
df = df.drop('Tipo servicio', axis=1, errors='ignore')

# %%
# Selecciona las columnas que contienen "Precio" en su nombre
price_columns = [col for col in df.columns if 'Precio' in col]
# Itera sobre las columnas de precio y reemplaza las comas por puntos y convierte a float
for column in price_columns:
    df[column] = df[column].astype(str).str.replace(',', '.').astype(float)

# Lista de columnas a verificar
columns_to_check = [
    'Margen',
    'Precio gasolina 95 E5 Premium',
    'Precio gasolina 98 E5',
    'Precio gasolina 98 E10',
    'Precio gasóleo Premium',
    'Precio gasóleo C',
    'Precio bioetanol',
    'Precio biodiésel',
    'Precio gases licuados del petróleo',
    'Precio gas natural comprimido',
    'Precio gas natural licuado',
    'Precio hidrógeno'
]
for column in columns_to_check:
    if column not in df.columns:
        df[column] = np.nan


# Convertirmos la columna Longitud y Latitud a numérica, cambiando la coma como separador decimal
df['Longitud'] = pd.to_numeric(df['Longitud'].str.replace(',', '.'), errors='coerce')
df['Latitud'] = pd.to_numeric(df['Latitud'].str.replace(',', '.'), errors='coerce')

# Convertirmos Toma de datos en datetime
df['Toma de datos'] = pd.to_datetime(df['Toma de datos'], errors='coerce') if 'Toma de datos' in df.columns else datetime.now().strftime('%Y-%m-%d %H:%M:%S')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131 entries, 0 to 130
# Data columns (total 28 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Provincia                           131 non-null    object
#  1   Municipio                           131 non-null    object
#  2   Localidad                           131 non-null    object
#  3   Código postal                       131 non-null    object
#  4   Dirección                           131 non-null    object
#  5   Longitud                            124 non-null    float64
#  6   Latitud                             124 non-null    float64
#  7   Precio gasolina 95 E5               78 non-null     float64
#  8   Precio gasolina 95 E10              1 non-null      float64
#  9   Precio gasóleo A                    82 non-null     float64
#  10  Precio gasóleo B                    73 non-null     float64
#  11  Precio gasóleo de uso marítimo      9 non-null      float64
#  12  Rótulo                              127 non-null    object
#  13  Horario                             131 non-null    object
#  14  Tipo estación                       131 non-null    object
#  15  Margen                              0 non-null      float64
#  16  Precio gasolina 95 E5 Premium       0 non-null      float64
#  17  Precio gasolina 98 E5               0 non-null      float64
#  18  Precio gasolina 98 E10              0 non-null      float64
#  19  Precio gasóleo Premium              0 non-null      float64
#  20  Precio gasóleo C                    0 non-null      float64
#  21  Precio bioetanol                    0 non-null      float64
#  22  Precio biodiésel                    0 non-null      float64
#  23  Precio gases licuados del petróleo  0 non-null      float64
#  24  Precio gas natural comprimido       0 non-null      float64
#  25  Precio gas natural licuado          0 non-null      float64
#  26  Precio hidrógeno                    0 non-null      float64
#  27  Toma de datos                       131 non-null    object
# dtypes: float64(19), object(9)
# memory usage: 28.8+ KB

# %%
df.head()
# Out:
#   Provincia             Municipio             Localidad Código postal  \
# 0  ALICANTE                 ALTEA                 ALTEA         03590
# 1  ALICANTE            CALPE/CALP                 CALPE         03710
# 2  ALICANTE                 DÉNIA                 DENIA         03700
# 3  ALICANTE                 DÉNIA                 DENIA         03700
# 4  ALICANTE  GUARDAMAR DEL SEGURA  GUARDAMAR DEL SEGURA         03140
#
#                                            Dirección  Longitud    Latitud  \
# 0  PUERTO DEPORTIVO LUIS CAMPOMANES, S/N - PARTID... -0.003833  38.629556
# 1                  EXPLANADA DEL PUERTO PESQUERO S/N  0.069162  38.637313
# 2                       PUERTO PESQUERO DE DENIA S/N  0.113056  38.843611
# 3               DARSENA DE BABOR S/N PUERTO DE DENIA  0.119139  38.567556
# 4                               AVDA. DEL PUERTO.219 -0.646278  38.109000
#
#    Precio gasolina 95 E5  Precio gasolina 95 E10  Precio gasóleo A  ...  \
# 0                  1.680                     NaN             1.550  ...
# 1                    NaN                     NaN               NaN  ...
# 2                    NaN                     NaN               NaN  ...
# 3                  1.669                     NaN             1.509  ...
# 4                    NaN                     NaN               NaN  ...
#
#    Precio gasolina 98 E10  Precio gasóleo Premium Precio gasóleo C  \
# 0                     NaN                     NaN              NaN
# 1                     NaN                     NaN              NaN
# 2                     NaN                     NaN              NaN
# 3                     NaN                     NaN              NaN
# 4                     NaN                     NaN              NaN
#
#   Precio bioetanol Precio biodiésel  Precio gases licuados del petróleo  \
# 0              NaN              NaN                                 NaN
# 1              NaN              NaN                                 NaN
# 2              NaN              NaN                                 NaN
# 3              NaN              NaN                                 NaN
# 4              NaN              NaN                                 NaN
#
#    Precio gas natural comprimido  Precio gas natural licuado  \
# 0                            NaN                         NaN
# 1                            NaN                         NaN
# 2                            NaN                         NaN
# 3                            NaN                         NaN
# 4                            NaN                         NaN
#
#    Precio hidrógeno        Toma de datos
# 0               NaN  2024-11-23 16:39:19
# 1               NaN  2024-11-23 16:39:19
# 2               NaN  2024-11-23 16:39:19
# 3               NaN  2024-11-23 16:39:19
# 4               NaN  2024-11-23 16:39:19
#
# [5 rows x 28 columns]

# %%
df.isnull().sum()  # Número de valores nulos por columna
# Out:
# Provincia                               0
# Municipio                               0
# Localidad                               0
# Código postal                           0
# Dirección                               0
# Longitud                                7
# Latitud                                 7
# Precio gasolina 95 E5                  53
# Precio gasolina 95 E10                130
# Precio gasóleo A                       49
# Precio gasóleo B                       58
# Precio gasóleo de uso marítimo        122
# Rótulo                                  4
# Horario                                 0
# Tipo estación                           0
# Margen                                131
# Precio gasolina 95 E5 Premium         131
# Precio gasolina 98 E5                 131
# Precio gasolina 98 E10                131
# Precio gasóleo Premium                131
# Precio gasóleo C                      131
# Precio bioetanol                      131
# Precio biodiésel                      131
# Precio gases licuados del petróleo    131
# Precio gas natural comprimido         131
# Precio gas natural licuado            131
# Precio hidrógeno                      131
# Toma de datos                           0
# dtype: int64

# %%
df.describe()  # Estadísticas descriptivas de las columnas numéricas
# Out:
#          Longitud     Latitud  Precio gasolina 95 E5  Precio gasolina 95 E10  \
# count  124.000000  124.000000              78.000000                   1.000
# mean    -3.506868   39.773314               1.592692                   1.636
# std      5.660443    4.147796               0.155482                     NaN
# min    -17.767333   27.746944               1.186000                   1.636
# 25%     -8.640199   38.635374               1.524750                   1.636
# 50%     -1.858040   40.665611               1.629500                   1.636
# 75%      0.961241   42.735180               1.680000                   1.636
# max      4.129750   43.737749               1.852000                   1.636
#
#        Precio gasóleo A  Precio gasóleo B  Precio gasóleo de uso marítimo  \
# count         82.000000         73.000000                        9.000000
# mean           1.493427        703.084932                      899.777778
# std            0.139393         64.364534                      361.211426
# min            1.110000        607.000000                      617.000000
# 25%            1.453000        666.000000                      673.000000
# 50%            1.522000        690.000000                      700.000000
# 75%            1.575000        720.000000                     1039.000000
# max            1.820000       1029.000000                     1540.000000
#
#        Margen  Precio gasolina 95 E5 Premium  Precio gasolina 98 E5  \
# count     0.0                            0.0                    0.0
# mean      NaN                            NaN                    NaN
# std       NaN                            NaN                    NaN
# min       NaN                            NaN                    NaN
# 25%       NaN                            NaN                    NaN
# 50%       NaN                            NaN                    NaN
# 75%       NaN                            NaN                    NaN
# max       NaN                            NaN                    NaN
#
#        Precio gasolina 98 E10  Precio gasóleo Premium  Precio gasóleo C  \
# count                     0.0                     0.0               0.0
# mean                      NaN                     NaN               NaN
# std                       NaN                     NaN               NaN
# min                       NaN                     NaN               NaN
# 25%                       NaN                     NaN               NaN
# 50%                       NaN                     NaN               NaN
# 75%                       NaN                     NaN               NaN
# max                       NaN                     NaN               NaN
#
#        Precio bioetanol  Precio biodiésel  Precio gases licuados del petróleo  \
# count               0.0               0.0                                 0.0
# mean                NaN               NaN                                 NaN
# std                 NaN               NaN                                 NaN
# min                 NaN               NaN                                 NaN
# 25%                 NaN               NaN                                 NaN
# 50%                 NaN               NaN                                 NaN
# 75%                 NaN               NaN                                 NaN
# max                 NaN               NaN                                 NaN
#
#        Precio gas natural comprimido  Precio gas natural licuado  \
# count                            0.0                         0.0
# mean                             NaN                         NaN
# std                              NaN                         NaN
# min                              NaN                         NaN
# 25%                              NaN                         NaN
# 50%                              NaN                         NaN
# 75%                              NaN                         NaN
# max                              NaN                         NaN
#
#        Precio hidrógeno
# count               0.0
# mean                NaN
# std                 NaN
# min                 NaN
# 25%                 NaN
# 50%                 NaN
# 75%                 NaN
# max                 NaN

# %%
# ordenamos columnas
df = df.reindex(columns=[
    'Provincia',
    'Municipio',
    'Localidad',
    'Código postal',
    'Dirección',
    'Margen',
    'Longitud',
    'Latitud',
    'Toma de datos',
    'Precio gasolina 95 E5',
    'Precio gasolina 95 E10',
    'Precio gasolina 95 E5 Premium',
    'Precio gasolina 98 E5',
    'Precio gasolina 98 E10',
    'Precio gasóleo A',
    'Precio gasóleo Premium',
    'Precio gasóleo B',
    'Precio gasóleo C',
    'Precio bioetanol',
    'Precio biodiésel',
    'Precio gases licuados del petróleo',
    'Precio gas natural comprimido',
    'Precio gas natural licuado',
    'Precio hidrógeno',
    'Rótulo',
    'Horario',
    'Tipo estación'
], fill_value=pd.NA)

# %%
# prompt: si el valor de la columna Tipo estación es "Puerto", dividimos entre 1000 el valor que tenga la columna  "Precio gasóleo B"

# Dividir entre 1000 la columna "Precio gasóleo B" si "Tipo estación" es "Puerto"
df.loc[df['Tipo estación'] == 'Puerto', 'Precio gasóleo B'] = df.loc[df['Tipo estación'] == 'Puerto', 'Precio gasóleo B'] / 1000

# %%
# prompt: Guarda en un fichero csv 1000 registros

# Seleccionar las primeras 1000 filas del DataFrame
#df_1000 = df.head(1000)

# Guardar el DataFrame en un archivo CSV
#df_1000.to_csv('primeras_1000_filas.csv', index=False, encoding='utf-8')

# %%
# Guardar el DataFrame completo en un archivo CSV
df.to_csv(file_price + '.csv', index=False, encoding='utf-8')
